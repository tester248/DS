# %%
# Install dependencies needed for this notebook (run once)
# %pip install -q nltk scikit-learn pandas
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Prac7 - Assignment 7
# **Group A**
# **Cell 1 — Goal:** Start with basic tokenization, stemming, and lemmatization.
# This notebook will demonstrate: sentence/word tokenization, Porter stemming, and WordNet lemmatization (with and without POS).

# %%
# Install / download required NLTK resources (first run may take a moment)
import nltk
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
print('NLTK resources ready')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# NLTK resources ready
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# **Cell 2 — Tokenization, POS tagging, Stemming, and Lemmatization demo**
# We use the sample text: `"studies studying cries cry Jupiter is the largest Planet"` to compare stemming vs lemmatization.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import pos_tag

text = 'studies studying cries cry Jupiter is the largest Planet'
# Tokenize
words = word_tokenize(text)
sentences = sent_tokenize(text)
print('Sentences:', sentences)
print('Words:', words)

# Stemming with PorterStemmer
ps = PorterStemmer()
stems = [ps.stem(w) for w in words]
print('Stems:', stems)

# Lemmatization (no POS)
lemmatizer = WordNetLemmatizer()
lemmas_no_pos = [lemmatizer.lemmatize(w) for w in words]
print('Lemmas (no POS):', lemmas_no_pos)

# POS tagging and lemmatization with POS mapping
pos_tags = pos_tag(words)
print('POS tags:', pos_tags)

def _map_pos(tag):
    if tag.startswith('J'):
        return 'a'
    elif tag.startswith('V'):
        return 'v'
    elif tag.startswith('N'):
        return 'n'
    elif tag.startswith('R'):
        return 'r'
    else:
        return 'n'

lemmas_with_pos = [lemmatizer.lemmatize(w, _map_pos(t)) for w,t in pos_tags]
print('Lemmas (with POS):', lemmas_with_pos)
# Out:
# Sentences: ['studies studying cries cry Jupiter is the largest Planet']
# Words: ['studies', 'studying', 'cries', 'cry', 'Jupiter', 'is', 'the', 'largest', 'Planet']
# Stems: ['studi', 'studi', 'cri', 'cri', 'jupit', 'is', 'the', 'largest', 'planet']
# Lemmas (no POS): ['study', 'studying', 'cry', 'cry', 'Jupiter', 'is', 'the', 'largest', 'Planet']
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[7], line 23
#      20 print('Lemmas (no POS):', lemmas_no_pos)
#      22 # POS tagging and lemmatization with POS mapping
# ---> 23 pos_tags = pos_tag(words)
#      24 print('POS tags:', pos_tags)
#      26 def _map_pos(tag):
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/nltk/tag/__init__.py:168, in pos_tag(tokens, tagset, lang)
#     143 def pos_tag(tokens, tagset=None, lang="eng"):
#     144     """
# ...

# %% [markdown]
# **Notes / next cell ideas:**
# - Show stop-word removal and lowercase conversion.
# - Then implement TF, IDF, and TF-IDF on a small corpus (cell-by-cell as requested).
